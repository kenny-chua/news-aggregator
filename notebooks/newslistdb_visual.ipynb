# %% [markdown]
# # Visualization of created SQLITE DB from API

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('../newslist.db')

# Query the database and load into a DataFrame
df = pd.read_sql_query("SELECT * FROM topheadline;", conn)

# Display the DataFrame
print(df)

# Close the connection
conn.close()
# Out:
#     id                source_id              source_name  \
# 0    1                     None                [Removed]
# 1    2                     None      Yahoo Entertainment
# 2    3                     espn                     ESPN
# 3    4                      cnn                      CNN
# 4    5                     None                [Removed]
# 5    6                     None                     CNBC
# 6    7                     None                  Variety
# 7    8      the-washington-post      The Washington Post
# 8    9                      cnn                      CNN
# 9   10                     None                 BBC News
# 10  11                 politico                 Politico
# 11  12                      cnn                      CNN
# 12  13                    axios                    Axios
# 13  14                     None                Space.com
# 14  15                      cnn                      CNN
# ...
